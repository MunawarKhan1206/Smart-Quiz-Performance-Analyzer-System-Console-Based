# %% [markdown]
# ###### Operator Procedures

# %% [raw]
# - pemdas
#     - P = parenthesis ()
#     - E = exponent (**)
#     - M = multiply (*)
#     - D = divide (//)
#     - A = addition (+)
#     - S = subtraction (-)

# %%
result = 12*90-18*(9+3)+90
# 12*90-18*(12)+90
# 1080-18*(12)+90
# 1080-216+90
# 1080-306

# %%
1080-306
# Out:
# 774

# %%
print(result)
# Out:
# 954

# %% [markdown]
# #### String Function Variable Define
#     - when we say string is immutable they can not be changed in memory
#     - ye string funtions only for temporary showing hy not save in memory

# %%
message = "hello python world!"

# %%
print(message)
# Out:
# hello python world!

# %%
print(message.lower()) # all letters lower
print(message.upper()) # ala letters UPPER
print(message.capitalize()) #first letter Capital
print(message.title()) #every first letter Capital
# Out:
# hello python world!
# HELLO PYTHON WORLD!
# Hello python world!
# Hello Python World!

# %%
# ap chahe to string funtion k bad usy variable me assign kr skty hy

# %%
message_2 = message.upper()
message_3 = message.capitalize()

# %%
print(message_2)
print(message_3)
# Out:
# HELLO PYTHON WORLD!
# Hello python world!
